# %%
from IPython.display import Image, display
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from time import sleep
from PIL import Image as Imag
import pyautogui

# %%
def perform():
    pyautogui.drag(-60, 0, 0, button='right')
    pyautogui.move(60, 0)
    pyautogui.drag(60, 0, 0, button='right')
    pyautogui.move(-60, 0)
    pyautogui.drag(0, 60, 0, button='right')
    pyautogui.move(0, -60)
    pyautogui.drag(0, -60, 0, button='right')
    pyautogui.move(0, 60)

# %%
def closeButtonLookup():
    if bool(pyautogui.locateCenterOnScreen('Images/btn_close.png', confidence=0.7))==True:
        x, y = pyautogui.locateCenterOnScreen('Images/btn_close.png', confidence=0.7)
        pyautogui.click(x/2, y/2, duration=0.3, button='right')
        print('OK,I am out of here!')
        return True
    return False

# %%
image = Imag.open("Images/game_board.png")
image_array = np.array(image)
imgplot = plt.imshow(image_array)

# %%
obstacle_array = image_array[930:1030,720:820]
imgplot = plt.imshow(obstacle_array)

# %%
image_array[900:].shape
# Out:
# (148, 1000, 4)

# %% [markdown]
# really 500x524

# %%
# screen size
pyautogui.size().height
# Out:
# 900

# %%
tile_w = 500/7
tile_h = 524/8

# %%
offset_x = tile_w/2
offset_y = tile_h/2

# %%
board_w = int(input('Tiles width: '))
# Out:
# Tiles width: 6

# %%
board_h = int(input('Tiles height: '))
# Out:
# Tiles height: 8

# %%
while True:
#     See if we are on the map yet
    if bool(pyautogui.locateOnScreen('Images/map.png', confidence=0.7))==True:
        print("I'm back to the map.")
        break
    if closeButtonLookup()==True:
        break
#     Set the start points
    start_x = tile_w+offset_x
    start_y = pyautogui.size().height - tile_h * (board_h) + offset_y
    pyautogui.moveTo(start_x, start_y) 
    for i in range((board_h)):
        if closeButtonLookup()==True:
            break
#         Step Horisontally 
        for j in range(board_w-2):
            perform()
            pyautogui.move(tile_w, 0)
#         Step vertically one tile lower
        start_y += tile_h  
        pyautogui.moveTo(start_x, start_y)
# Out:
# I am out of here
# I am out of here
# I am out of here
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-619-d23e013d9c41> in <module>
#       4         print("I'm back to the map.")
#       5         break
# ----> 6     if closeButtonLookup()==True:
#       7         break
#       8 #     Set the start points
#
# <ipython-input-602-bc6f6b88c980> in closeButtonLookup()
#       1 def closeButtonLookup():
# ----> 2     if bool(pyautogui.locateCenterOnScreen('Images/btn_close.png', confidence=0.7))==True:
#       3         x, y = pyautogui.locateCenterOnScreen('Images/btn_close.png', confidence=0.7)
#       4         pyautogui.click(x/2, y/2, duration=0.3, button='right')
#       5         print('I am out of here')
#
# ~/Library/Python/3.8/lib/python/site-packages/pyautogui/__init__.py in wrapper(*args, **kwargs)
#     173     def wrapper(*args, **kwargs):
#     174         try:
# --> 175             return wrappedFunction(*args, **kwargs)
#     176         except pyscreeze.ImageNotFoundException:
#     177             raise ImageNotFoundException  # Raise PyAutoGUI's ImageNotFoundException.
#
# ~/Library/Python/3.8/lib/python/site-packages/pyautogui/__init__.py in locateCenterOnScreen(*args, **kwargs)
#     205     @raisePyAutoGUIImageNotFoundException
#     206     def locateCenterOnScreen(*args, **kwargs):
# --> 207         return pyscreeze.locateCenterOnScreen(*args, **kwargs)
#     208
#     209     locateCenterOnScreen.__doc__ = pyscreeze.locateCenterOnScreen.__doc__
#
# ~/Library/Python/3.8/lib/python/site-packages/pyscreeze/__init__.py in locateCenterOnScreen(image, **kwargs)
#     411     TODO
#     412     """
# --> 413     coords = locateOnScreen(image, **kwargs)
#     414     if coords is None:
#     415         return None
#
# ~/Library/Python/3.8/lib/python/site-packages/pyscreeze/__init__.py in locateOnScreen(image, minSearchTime, **kwargs)
#     371         try:
#     372             screenshotIm = screenshot(region=None) # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
# --> 373             retVal = locate(image, screenshotIm, **kwargs)
#     374             try:
#     375                 screenshotIm.fp.close()
#
# ~/Library/Python/3.8/lib/python/site-packages/pyscreeze/__init__.py in locate(needleImage, haystackImage, **kwargs)
#     351     # Note: The gymnastics in this function is because we want to make sure to exhaust the iterator so that the needle and haystack files are closed in locateAll.
#     352     kwargs['limit'] = 1
# --> 353     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     354     if len(points) > 0:
#     355         return points[0]
#
# ~/Library/Python/3.8/lib/python/site-packages/pyscreeze/__init__.py in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     227
#     228     # get all matches at once, credit: https://stackoverflow.com/questions/7670112/finding-a-subimage-inside-a-numpy-image/9253805#9253805
# --> 229     result = cv2.matchTemplate(haystackImage, needleImage, cv2.TM_CCOEFF_NORMED)
#     230     match_indices = numpy.arange(result.size)[(result > confidence).flatten()]
#     231     matches = numpy.unravel_index(match_indices[:limit], result.shape)
#
# KeyboardInterrupt:

# %%
pyautogui.click(duration=0.1, button='right')

# %%
x, y = pyautogui.locateCenterOnScreen('Images/btn_close.png', confidence=0.9)
pyautogui.click(x/2, y/2, button='right')

# %%
img ='Images/btn_close.png'
display(Image(img))

# %%
pyautogui.click(x, y, button='right')

# %%
pyautogui.position()
# Out:
# Point(x=381, y=461)

# %%
from math import ceil

# %%
pyautogui.locateOnScreen('Images/map.png', confidence=0.7)
# Out:
# Box(left=777, top=523, width=250, height=243)

# %%
bool(pyautogui.locateOnScreen('Images/map.png', confidence=0.7))
# Out:
# True
