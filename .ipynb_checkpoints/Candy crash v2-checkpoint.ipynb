# %%
from IPython.display import Image, display
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from time import sleep
from PIL import Image as Imag
import pyautogui
from math import ceil

# %%
game_bo

# %%
def perform(box):
    '''Moves the mouse to the box location.
    Performs one tile mousedrag in for directions '''
    pyautogui.moveTo(box[0], box[1])
    pyautogui.drag(-60, 0, 0, button='right')
    pyautogui.move(60, 0)
    pyautogui.drag(60, 0, 0, button='right')
    pyautogui.move(-60, 0)
    pyautogui.drag(0, 60, 0, button='right')
    pyautogui.move(0, -60)
    pyautogui.drag(0, -60, 0, button='right')
    pyautogui.move(0, 60)

# %%
tile_w = 500/7
tile_h = 524/8

# %%
offset_x = tile_w/2
offset_y = tile_h/2

# %% [markdown]
# Locate all blue candies on screen.

# %%
all_g = list(pyautogui.locateAllOnScreen('Images/bluefake.png', confidence=0.9))

# %%
all_g
# Out:
# [Box(left=1312, top=565, width=164, height=144),
#  Box(left=1313, top=565, width=164, height=144),
#  Box(left=1314, top=565, width=164, height=144),
#  Box(left=1315, top=565, width=164, height=144),
#  Box(left=776, top=566, width=164, height=144),
#  Box(left=777, top=566, width=164, height=144),
#  Box(left=778, top=566, width=164, height=144),
#  Box(left=779, top=566, width=164, height=144),
#  Box(left=780, top=566, width=164, height=144),
#  Box(left=781, top=566, width=164, height=144),
#  Box(left=1310, top=566, width=164, height=144),
#  Box(left=1311, top=566, width=164, height=144),
#  Box(left=1312, top=566, width=164, height=144),
#  Box(left=1313, top=566, width=164, height=144),
#  Box(left=1314, top=566, width=164, height=144),
#  Box(left=1315, top=566, width=164, height=144),
#  Box(left=1316, top=566, width=164, height=144),
#  Box(left=1317, top=566, width=164, height=144),
#  Box(left=775, top=567, width=164, height=144),
#  Box(left=776, top=567, width=164, height=144),
#  Box(left=777, top=567, width=164, height=144),
#  Box(left=778, top=567, width=164, height=144),
#  Box(left=779, top=567, width=164, height=144),
#  Box(left=780, top=567, width=164, height=144),
#  Box(left=781, top=567, width=164, height=144),
#  Box(left=782, top=567, width=164, height=144),
#  Box(left=1310, top=567, width=164, height=144),
#  Box(left=1311, top=567, width=164, height=144),
#  Box(left=1312, top=567, width=164, height=144),
#  Box(left=1313, top=567, width=164, height=144),
#  Box(left=1314, top=567, width=164, height=144),
#  Box(left=1315, top=567, width=164, height=144),
#  Box(left=1316, top=567, width=164, height=144),
#  Box(left=1317, top=567, width=164, height=144),
#  Box(left=1318, top=567, width=164, height=144),
#  Box(left=775, top=568, width=164, height=144),
#  Box(left=776, top=568, width=164, height=144),
#  Box(left=777, top=568, width=164, height=144),
#  Box(left=778, top=568, width=164, height=144),
#  Box(left=779, top=568, width=164, height=144),
#  Box(left=780, top=568, width=164, height=144),
#  Box(left=781, top=568, width=164, height=144),
#  Box(left=782, top=568, width=164, height=144),
#  Box(left=1310, top=568, width=164, height=144),
#  Box(left=1311, top=568, width=164, height=144),
#  Box(left=1312, top=568, width=164, height=144),
#  Box(left=1313, top=568, width=164, height=144),
#  Box(left=1314, top=568, width=164, height=144),
#  Box(left=1315, top=568, width=164, height=144),
#  Box(left=1316, top=568, width=164, height=144),
#  Box(left=1317, top=568, width=164, height=144),
#  Box(left=1318, top=568, width=164, height=144),
#  Box(left=775, top=569, width=164, height=144),
#  Box(left=776, top=569, width=164, height=144),
#  Box(left=777, top=569, width=164, height=144),
#  Box(left=778, top=569, width=164, height=144),
#  Box(left=779, top=569, width=164, height=144),
#  Box(left=780, top=569, width=164, height=144),
#  Box(left=781, top=569, width=164, height=144),
#  Box(left=782, top=569, width=164, height=144),
#  Box(left=1310, top=569, width=164, height=144),
#  Box(left=1311, top=569, width=164, height=144),
#  Box(left=1312, top=569, width=164, height=144),
#  Box(left=1313, top=569, width=164, height=144),
#  Box(left=1314, top=569, width=164, height=144),
#  Box(left=1315, top=569, width=164, height=144),
#  Box(left=1316, top=569, width=164, height=144),
#  Box(left=1317, top=569, width=164, height=144),
#  Box(left=1318, top=569, width=164, height=144),
#  Box(left=776, top=570, width=164, height=144),
#  Box(left=777, top=570, width=164, height=144),
#  Box(left=778, top=570, width=164, height=144),
#  Box(left=779, top=570, width=164, height=144),
#  Box(left=780, top=570, width=164, height=144),
#  Box(left=781, top=570, width=164, height=144),
#  Box(left=782, top=570, width=164, height=144),
#  Box(left=1311, top=570, width=164, height=144),
#  Box(left=1312, top=570, width=164, height=144),
#  Box(left=1313, top=570, width=164, height=144),
#  Box(left=1314, top=570, width=164, height=144),
#  Box(left=1315, top=570, width=164, height=144),
#  Box(left=1316, top=570, width=164, height=144),
#  Box(left=1317, top=570, width=164, height=144),
#  Box(left=1318, top=570, width=164, height=144),
#  Box(left=779, top=571, width=164, height=144),
#  Box(left=780, top=571, width=164, height=144),
#  Box(left=1313, top=571, width=164, height=144),
#  Box(left=1314, top=571, width=164, height=144),
#  Box(left=1315, top=571, width=164, height=144),
#  Box(left=1316, top=571, width=164, height=144),
#  Box(left=1311, top=730, width=164, height=144),
#  Box(left=1312, top=730, width=164, height=144),
#  Box(left=1313, top=730, width=164, height=144),
#  Box(left=1314, top=730, width=164, height=144),
#  Box(left=1315, top=730, width=164, height=144),
#  Box(left=1316, top=730, width=164, height=144),
#  Box(left=1310, top=731, width=164, height=144),
#  Box(left=1311, top=731, width=164, height=144),
#  Box(left=1312, top=731, width=164, height=144),
#  Box(left=1313, top=731, width=164, height=144),
#  Box(left=1314, top=731, width=164, height=144),
#  Box(left=1315, top=731, width=164, height=144),
#  Box(left=1316, top=731, width=164, height=144),
#  Box(left=1317, top=731, width=164, height=144),
#  Box(left=1310, top=732, width=164, height=144),
#  Box(left=1311, top=732, width=164, height=144),
#  Box(left=1312, top=732, width=164, height=144),
#  Box(left=1313, top=732, width=164, height=144),
#  Box(left=1314, top=732, width=164, height=144),
#  Box(left=1315, top=732, width=164, height=144),
#  Box(left=1316, top=732, width=164, height=144),
#  Box(left=1317, top=732, width=164, height=144),
#  Box(left=1318, top=732, width=164, height=144),
#  Box(left=1310, top=733, width=164, height=144),
#  Box(left=1311, top=733, width=164, height=144),
#  Box(left=1312, top=733, width=164, height=144),
#  Box(left=1313, top=733, width=164, height=144),
#  Box(left=1314, top=733, width=164, height=144),
#  Box(left=1315, top=733, width=164, height=144),
#  Box(left=1316, top=733, width=164, height=144),
#  Box(left=1317, top=733, width=164, height=144),
#  Box(left=1318, top=733, width=164, height=144),
#  Box(left=1311, top=734, width=164, height=144),
#  Box(left=1312, top=734, width=164, height=144),
#  Box(left=1313, top=734, width=164, height=144),
#  Box(left=1314, top=734, width=164, height=144),
#  Box(left=1315, top=734, width=164, height=144),
#  Box(left=1316, top=734, width=164, height=144),
#  Box(left=1317, top=734, width=164, height=144),
#  Box(left=1318, top=734, width=164, height=144),
#  Box(left=1312, top=735, width=164, height=144),
#  Box(left=1313, top=735, width=164, height=144),
#  Box(left=1314, top=735, width=164, height=144),
#  Box(left=1315, top=735, width=164, height=144),
#  Box(left=1316, top=735, width=164, height=144),
#  Box(left=1317, top=735, width=164, height=144),
#  Box(left=599, top=894, width=164, height=144),
#  Box(left=600, top=894, width=164, height=144),
#  Box(left=1491, top=894, width=164, height=144),
#  Box(left=1492, top=894, width=164, height=144),
#  Box(left=1493, top=894, width=164, height=144),
#  Box(left=597, top=895, width=164, height=144),
#  Box(left=598, top=895, width=164, height=144),
#  Box(left=599, top=895, width=164, height=144),
#  Box(left=600, top=895, width=164, height=144),
#  Box(left=601, top=895, width=164, height=144),
#  Box(left=602, top=895, width=164, height=144),
#  Box(left=603, top=895, width=164, height=144),
#  Box(left=1489, top=895, width=164, height=144),
#  Box(left=1490, top=895, width=164, height=144),
#  Box(left=1491, top=895, width=164, height=144),
#  Box(left=1492, top=895, width=164, height=144),
#  Box(left=1493, top=895, width=164, height=144),
#  Box(left=1494, top=895, width=164, height=144),
#  Box(left=1495, top=895, width=164, height=144),
#  Box(left=597, top=896, width=164, height=144),
#  Box(left=598, top=896, width=164, height=144),
#  Box(left=599, top=896, width=164, height=144),
#  Box(left=600, top=896, width=164, height=144),
#  Box(left=601, top=896, width=164, height=144),
#  Box(left=602, top=896, width=164, height=144),
#  Box(left=603, top=896, width=164, height=144),
#  Box(left=1489, top=896, width=164, height=144),
#  Box(left=1490, top=896, width=164, height=144),
#  Box(left=1491, top=896, width=164, height=144),
#  Box(left=1492, top=896, width=164, height=144),
#  Box(left=1493, top=896, width=164, height=144),
#  Box(left=1494, top=896, width=164, height=144),
#  Box(left=1495, top=896, width=164, height=144),
#  Box(left=1496, top=896, width=164, height=144),
#  Box(left=597, top=897, width=164, height=144),
#  Box(left=598, top=897, width=164, height=144),
#  Box(left=599, top=897, width=164, height=144),
#  Box(left=600, top=897, width=164, height=144),
#  Box(left=601, top=897, width=164, height=144),
#  Box(left=602, top=897, width=164, height=144),
#  Box(left=603, top=897, width=164, height=144),
#  Box(left=604, top=897, width=164, height=144),
#  Box(left=1489, top=897, width=164, height=144),
#  Box(left=1490, top=897, width=164, height=144),
#  Box(left=1491, top=897, width=164, height=144),
#  Box(left=1492, top=897, width=164, height=144),
#  Box(left=1493, top=897, width=164, height=144),
#  Box(left=1494, top=897, width=164, height=144),
#  Box(left=1495, top=897, width=164, height=144),
#  Box(left=1496, top=897, width=164, height=144),
#  Box(left=597, top=898, width=164, height=144),
#  Box(left=598, top=898, width=164, height=144),
#  Box(left=599, top=898, width=164, height=144),
#  Box(left=600, top=898, width=164, height=144),
#  Box(left=601, top=898, width=164, height=144),
#  Box(left=602, top=898, width=164, height=144),
#  Box(left=603, top=898, width=164, height=144),
#  Box(left=604, top=898, width=164, height=144),
#  Box(left=1489, top=898, width=164, height=144),
#  Box(left=1490, top=898, width=164, height=144),
#  Box(left=1491, top=898, width=164, height=144),
#  Box(left=1492, top=898, width=164, height=144),
#  Box(left=1493, top=898, width=164, height=144),
#  Box(left=1494, top=898, width=164, height=144),
#  Box(left=1495, top=898, width=164, height=144),
#  Box(left=1496, top=898, width=164, height=144),
#  Box(left=598, top=899, width=164, height=144),
#  Box(left=599, top=899, width=164, height=144),
#  Box(left=600, top=899, width=164, height=144),
#  Box(left=601, top=899, width=164, height=144),
#  Box(left=602, top=899, width=164, height=144),
#  Box(left=603, top=899, width=164, height=144),
#  Box(left=1490, top=899, width=164, height=144),
#  Box(left=1491, top=899, width=164, height=144),
#  Box(left=1492, top=899, width=164, height=144),
#  Box(left=1493, top=899, width=164, height=144),
#  Box(left=1494, top=899, width=164, height=144),
#  Box(left=1495, top=899, width=164, height=144),
#  Box(left=1493, top=900, width=164, height=144),
#  Box(left=1311, top=1059, width=164, height=144),
#  Box(left=1312, top=1059, width=164, height=144),
#  Box(left=1313, top=1059, width=164, height=144),
#  Box(left=1314, top=1059, width=164, height=144),
#  Box(left=1315, top=1059, width=164, height=144),
#  Box(left=1316, top=1059, width=164, height=144),
#  Box(left=1490, top=1059, width=164, height=144),
#  Box(left=1491, top=1059, width=164, height=144),
#  Box(left=1492, top=1059, width=164, height=144),
#  Box(left=1493, top=1059, width=164, height=144),
#  Box(left=1494, top=1059, width=164, height=144),
#  Box(left=1495, top=1059, width=164, height=144),
#  Box(left=1310, top=1060, width=164, height=144),
#  Box(left=1311, top=1060, width=164, height=144),
#  Box(left=1312, top=1060, width=164, height=144),
#  Box(left=1313, top=1060, width=164, height=144),
#  Box(left=1314, top=1060, width=164, height=144),
#  Box(left=1315, top=1060, width=164, height=144),
#  Box(left=1316, top=1060, width=164, height=144),
#  Box(left=1317, top=1060, width=164, height=144),
#  Box(left=1489, top=1060, width=164, height=144),
#  Box(left=1490, top=1060, width=164, height=144),
#  Box(left=1491, top=1060, width=164, height=144),
#  Box(left=1492, top=1060, width=164, height=144),
#  Box(left=1493, top=1060, width=164, height=144),
#  Box(left=1494, top=1060, width=164, height=144),
#  Box(left=1495, top=1060, width=164, height=144),
#  Box(left=1496, top=1060, width=164, height=144),
#  Box(left=1310, top=1061, width=164, height=144),
#  Box(left=1311, top=1061, width=164, height=144),
#  Box(left=1312, top=1061, width=164, height=144),
#  Box(left=1313, top=1061, width=164, height=144),
#  Box(left=1314, top=1061, width=164, height=144),
#  Box(left=1315, top=1061, width=164, height=144),
#  Box(left=1316, top=1061, width=164, height=144),
#  Box(left=1317, top=1061, width=164, height=144),
#  Box(left=1318, top=1061, width=164, height=144),
#  Box(left=1489, top=1061, width=164, height=144),
#  Box(left=1490, top=1061, width=164, height=144),
#  Box(left=1491, top=1061, width=164, height=144),
#  Box(left=1492, top=1061, width=164, height=144),
#  Box(left=1493, top=1061, width=164, height=144),
#  Box(left=1494, top=1061, width=164, height=144),
#  Box(left=1495, top=1061, width=164, height=144),
#  Box(left=1496, top=1061, width=164, height=144),
#  Box(left=1310, top=1062, width=164, height=144),
#  Box(left=1311, top=1062, width=164, height=144),
#  Box(left=1312, top=1062, width=164, height=144),
#  Box(left=1313, top=1062, width=164, height=144),
#  Box(left=1314, top=1062, width=164, height=144),
#  Box(left=1315, top=1062, width=164, height=144),
#  Box(left=1316, top=1062, width=164, height=144),
#  Box(left=1317, top=1062, width=164, height=144),
#  Box(left=1318, top=1062, width=164, height=144),
#  Box(left=1489, top=1062, width=164, height=144),
#  Box(left=1490, top=1062, width=164, height=144),
#  Box(left=1491, top=1062, width=164, height=144),
#  Box(left=1492, top=1062, width=164, height=144),
#  Box(left=1493, top=1062, width=164, height=144),
#  Box(left=1494, top=1062, width=164, height=144),
#  Box(left=1495, top=1062, width=164, height=144),
#  Box(left=1496, top=1062, width=164, height=144),
#  Box(left=1311, top=1063, width=164, height=144),
#  Box(left=1312, top=1063, width=164, height=144),
#  Box(left=1313, top=1063, width=164, height=144),
#  Box(left=1314, top=1063, width=164, height=144),
#  Box(left=1315, top=1063, width=164, height=144),
#  Box(left=1316, top=1063, width=164, height=144),
#  Box(left=1317, top=1063, width=164, height=144),
#  Box(left=1318, top=1063, width=164, height=144),
#  Box(left=1490, top=1063, width=164, height=144),
#  Box(left=1491, top=1063, width=164, height=144),
#  Box(left=1492, top=1063, width=164, height=144),
#  Box(left=1493, top=1063, width=164, height=144),
#  Box(left=1494, top=1063, width=164, height=144),
#  Box(left=1495, top=1063, width=164, height=144),
#  Box(left=1496, top=1063, width=164, height=144),
#  Box(left=1312, top=1064, width=164, height=144),
#  Box(left=1313, top=1064, width=164, height=144),
#  Box(left=1314, top=1064, width=164, height=144),
#  Box(left=1315, top=1064, width=164, height=144),
#  Box(left=1316, top=1064, width=164, height=144),
#  Box(left=1492, top=1064, width=164, height=144),
#  Box(left=1493, top=1064, width=164, height=144),
#  Box(left=1494, top=1064, width=164, height=144),
#  Box(left=1495, top=1064, width=164, height=144),
#  Box(left=420, top=1223, width=164, height=144),
#  Box(left=421, top=1223, width=164, height=144),
#  Box(left=422, top=1223, width=164, height=144),
#  Box(left=1134, top=1223, width=164, height=144),
#  Box(left=1135, top=1223, width=164, height=144),
#  Box(left=1136, top=1223, width=164, height=144),
#  Box(left=419, top=1224, width=164, height=144),
#  Box(left=420, top=1224, width=164, height=144),
#  Box(left=421, top=1224, width=164, height=144),
#  Box(left=422, top=1224, width=164, height=144),
#  Box(left=423, top=1224, width=164, height=144),
#  Box(left=424, top=1224, width=164, height=144),
#  Box(left=1133, top=1224, width=164, height=144),
#  Box(left=1134, top=1224, width=164, height=144),
#  Box(left=1135, top=1224, width=164, height=144),
#  Box(left=1136, top=1224, width=164, height=144),
#  Box(left=1137, top=1224, width=164, height=144),
#  Box(left=1138, top=1224, width=164, height=144),
#  Box(left=418, top=1225, width=164, height=144),
#  Box(left=419, top=1225, width=164, height=144),
#  Box(left=420, top=1225, width=164, height=144),
#  Box(left=421, top=1225, width=164, height=144),
#  Box(left=422, top=1225, width=164, height=144),
#  Box(left=423, top=1225, width=164, height=144),
#  Box(left=424, top=1225, width=164, height=144),
#  Box(left=425, top=1225, width=164, height=144),
#  Box(left=1132, top=1225, width=164, height=144),
#  Box(left=1133, top=1225, width=164, height=144),
#  Box(left=1134, top=1225, width=164, height=144),
#  Box(left=1135, top=1225, width=164, height=144),
#  Box(left=1136, top=1225, width=164, height=144),
#  Box(left=1137, top=1225, width=164, height=144),
#  Box(left=1138, top=1225, width=164, height=144),
#  Box(left=1139, top=1225, width=164, height=144),
#  Box(left=418, top=1226, width=164, height=144),
#  Box(left=419, top=1226, width=164, height=144),
#  Box(left=420, top=1226, width=164, height=144),
#  Box(left=421, top=1226, width=164, height=144),
#  Box(left=422, top=1226, width=164, height=144),
#  Box(left=423, top=1226, width=164, height=144),
#  Box(left=424, top=1226, width=164, height=144),
#  Box(left=425, top=1226, width=164, height=144),
#  Box(left=1132, top=1226, width=164, height=144),
#  Box(left=1133, top=1226, width=164, height=144),
#  Box(left=1134, top=1226, width=164, height=144),
#  Box(left=1135, top=1226, width=164, height=144),
#  Box(left=1136, top=1226, width=164, height=144),
#  Box(left=1137, top=1226, width=164, height=144),
#  Box(left=1138, top=1226, width=164, height=144),
#  Box(left=1139, top=1226, width=164, height=144),
#  Box(left=419, top=1227, width=164, height=144),
#  Box(left=420, top=1227, width=164, height=144),
#  Box(left=421, top=1227, width=164, height=144),
#  Box(left=422, top=1227, width=164, height=144),
#  Box(left=423, top=1227, width=164, height=144),
#  Box(left=424, top=1227, width=164, height=144),
#  Box(left=425, top=1227, width=164, height=144),
#  Box(left=1133, top=1227, width=164, height=144),
#  Box(left=1134, top=1227, width=164, height=144),
#  Box(left=1135, top=1227, width=164, height=144),
#  Box(left=1136, top=1227, width=164, height=144),
#  Box(left=1137, top=1227, width=164, height=144),
#  Box(left=1138, top=1227, width=164, height=144),
#  Box(left=1139, top=1227, width=164, height=144),
#  Box(left=420, top=1228, width=164, height=144),
#  Box(left=421, top=1228, width=164, height=144),
#  Box(left=422, top=1228, width=164, height=144),
#  Box(left=423, top=1228, width=164, height=144),
#  Box(left=424, top=1228, width=164, height=144),
#  Box(left=1134, top=1228, width=164, height=144),
#  Box(left=1135, top=1228, width=164, height=144),
#  Box(left=1136, top=1228, width=164, height=144),
#  Box(left=1137, top=1228, width=164, height=144),
#  Box(left=1138, top=1228, width=164, height=144),
#  Box(left=598, top=1388, width=164, height=144),
#  Box(left=599, top=1388, width=164, height=144),
#  Box(left=600, top=1388, width=164, height=144),
#  Box(left=601, top=1388, width=164, height=144),
#  Box(left=602, top=1388, width=164, height=144),
#  Box(left=1311, top=1388, width=164, height=144),
#  Box(left=1312, top=1388, width=164, height=144),
#  Box(left=1313, top=1388, width=164, height=144),
#  Box(left=1314, top=1388, width=164, height=144),
#  Box(left=1315, top=1388, width=164, height=144),
#  Box(left=1316, top=1388, width=164, height=144),
#  Box(left=597, top=1389, width=164, height=144),
#  Box(left=598, top=1389, width=164, height=144),
#  Box(left=599, top=1389, width=164, height=144),
#  Box(left=600, top=1389, width=164, height=144),
#  Box(left=601, top=1389, width=164, height=144),
#  Box(left=602, top=1389, width=164, height=144),
#  Box(left=603, top=1389, width=164, height=144),
#  Box(left=1311, top=1389, width=164, height=144),
#  Box(left=1312, top=1389, width=164, height=144),
#  Box(left=1313, top=1389, width=164, height=144),
#  Box(left=1314, top=1389, width=164, height=144),
#  Box(left=1315, top=1389, width=164, height=144),
#  Box(left=1316, top=1389, width=164, height=144),
#  Box(left=1317, top=1389, width=164, height=144),
#  Box(left=597, top=1390, width=164, height=144),
#  Box(left=598, top=1390, width=164, height=144),
#  Box(left=599, top=1390, width=164, height=144),
#  Box(left=600, top=1390, width=164, height=144),
#  Box(left=601, top=1390, width=164, height=144),
#  Box(left=602, top=1390, width=164, height=144),
#  Box(left=603, top=1390, width=164, height=144),
#  Box(left=604, top=1390, width=164, height=144),
#  Box(left=1310, top=1390, width=164, height=144),
#  Box(left=1311, top=1390, width=164, height=144),
#  Box(left=1312, top=1390, width=164, height=144),
#  Box(left=1313, top=1390, width=164, height=144),
#  Box(left=1314, top=1390, width=164, height=144),
#  Box(left=1315, top=1390, width=164, height=144),
#  Box(left=1316, top=1390, width=164, height=144),
#  Box(left=1317, top=1390, width=164, height=144),
#  Box(left=1318, top=1390, width=164, height=144),
#  Box(left=597, top=1391, width=164, height=144),
#  Box(left=598, top=1391, width=164, height=144),
#  Box(left=599, top=1391, width=164, height=144),
#  Box(left=600, top=1391, width=164, height=144),
#  Box(left=601, top=1391, width=164, height=144),
#  Box(left=602, top=1391, width=164, height=144),
#  Box(left=603, top=1391, width=164, height=144),
#  Box(left=604, top=1391, width=164, height=144),
#  Box(left=1311, top=1391, width=164, height=144),
#  Box(left=1312, top=1391, width=164, height=144),
#  Box(left=1313, top=1391, width=164, height=144),
#  Box(left=1314, top=1391, width=164, height=144),
#  Box(left=1315, top=1391, width=164, height=144),
#  Box(left=1316, top=1391, width=164, height=144),
#  Box(left=1317, top=1391, width=164, height=144),
#  Box(left=1318, top=1391, width=164, height=144),
#  Box(left=598, top=1392, width=164, height=144),
#  Box(left=599, top=1392, width=164, height=144),
#  Box(left=600, top=1392, width=164, height=144),
#  Box(left=601, top=1392, width=164, height=144),
#  Box(left=602, top=1392, width=164, height=144),
#  Box(left=603, top=1392, width=164, height=144),
#  Box(left=1312, top=1392, width=164, height=144),
#  Box(left=1313, top=1392, width=164, height=144),
#  Box(left=1314, top=1392, width=164, height=144),
#  Box(left=1315, top=1392, width=164, height=144),
#  Box(left=1316, top=1392, width=164, height=144),
#  Box(left=1317, top=1392, width=164, height=144),
#  Box(left=601, top=1393, width=164, height=144),
#  Box(left=1314, top=1393, width=164, height=144),
#  Box(left=1315, top=1393, width=164, height=144)]

# %%
arr = np.array([[box.left, box.top] for box in all_g])

# %%
fig, ax = plt.subplots()
ax.scatter(arr[:,0],arr[:,1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
arr[1:]
# Out:
# array([[1313,  565],
#        [1314,  565],
#        [1315,  565],
#        [ 776,  566],
#        [ 777,  566],
#        [ 778,  566],
#        [ 779,  566],
#        [ 780,  566],
#        [ 781,  566],
#        [1310,  566],
#        [1311,  566],
#        [1312,  566],
#        [1313,  566],
#        [1314,  566],
#        [1315,  566],
#        [1316,  566],
#        [1317,  566],
#        [ 775,  567],
#        [ 776,  567],
#        [ 777,  567],
#        [ 778,  567],
#        [ 779,  567],
#        [ 780,  567],
#        [ 781,  567],
#        [ 782,  567],
#        [1310,  567],
#        [1311,  567],
#        [1312,  567],
#        [1313,  567],
#        [1314,  567],
#        [1315,  567],
#        [1316,  567],
#        [1317,  567],
#        [1318,  567],
#        [ 775,  568],
#        [ 776,  568],
#        [ 777,  568],
#        [ 778,  568],
#        [ 779,  568],
#        [ 780,  568],
#        [ 781,  568],
#        [ 782,  568],
#        [1310,  568],
#        [1311,  568],
#        [1312,  568],
#        [1313,  568],
#        [1314,  568],
#        [1315,  568],
#        [1316,  568],
#        [1317,  568],
#        [1318,  568],
#        [ 775,  569],
#        [ 776,  569],
#        [ 777,  569],
#        [ 778,  569],
#        [ 779,  569],
#        [ 780,  569],
#        [ 781,  569],
#        [ 782,  569],
#        [1310,  569],
#        [1311,  569],
#        [1312,  569],
#        [1313,  569],
#        [1314,  569],
#        [1315,  569],
#        [1316,  569],
#        [1317,  569],
#        [1318,  569],
#        [ 776,  570],
#        [ 777,  570],
#        [ 778,  570],
#        [ 779,  570],
#        [ 780,  570],
#        [ 781,  570],
#        [ 782,  570],
#        [1311,  570],
#        [1312,  570],
#        [1313,  570],
#        [1314,  570],
#        [1315,  570],
#        [1316,  570],
#        [1317,  570],
#        [1318,  570],
#        [ 779,  571],
#        [ 780,  571],
#        [1313,  571],
#        [1314,  571],
#        [1315,  571],
#        [1316,  571],
#        [1311,  730],
#        [1312,  730],
#        [1313,  730],
#        [1314,  730],
#        [1315,  730],
#        [1316,  730],
#        [1310,  731],
#        [1311,  731],
#        [1312,  731],
#        [1313,  731],
#        [1314,  731],
#        [1315,  731],
#        [1316,  731],
#        [1317,  731],
#        [1310,  732],
#        [1311,  732],
#        [1312,  732],
#        [1313,  732],
#        [1314,  732],
#        [1315,  732],
#        [1316,  732],
#        [1317,  732],
#        [1318,  732],
#        [1310,  733],
#        [1311,  733],
#        [1312,  733],
#        [1313,  733],
#        [1314,  733],
#        [1315,  733],
#        [1316,  733],
#        [1317,  733],
#        [1318,  733],
#        [1311,  734],
#        [1312,  734],
#        [1313,  734],
#        [1314,  734],
#        [1315,  734],
#        [1316,  734],
#        [1317,  734],
#        [1318,  734],
#        [1312,  735],
#        [1313,  735],
#        [1314,  735],
#        [1315,  735],
#        [1316,  735],
#        [1317,  735],
#        [ 599,  894],
#        [ 600,  894],
#        [1491,  894],
#        [1492,  894],
#        [1493,  894],
#        [ 597,  895],
#        [ 598,  895],
#        [ 599,  895],
#        [ 600,  895],
#        [ 601,  895],
#        [ 602,  895],
#        [ 603,  895],
#        [1489,  895],
#        [1490,  895],
#        [1491,  895],
#        [1492,  895],
#        [1493,  895],
#        [1494,  895],
#        [1495,  895],
#        [ 597,  896],
#        [ 598,  896],
#        [ 599,  896],
#        [ 600,  896],
#        [ 601,  896],
#        [ 602,  896],
#        [ 603,  896],
#        [1489,  896],
#        [1490,  896],
#        [1491,  896],
#        [1492,  896],
#        [1493,  896],
#        [1494,  896],
#        [1495,  896],
#        [1496,  896],
#        [ 597,  897],
#        [ 598,  897],
#        [ 599,  897],
#        [ 600,  897],
#        [ 601,  897],
#        [ 602,  897],
#        [ 603,  897],
#        [ 604,  897],
#        [1489,  897],
#        [1490,  897],
#        [1491,  897],
#        [1492,  897],
#        [1493,  897],
#        [1494,  897],
#        [1495,  897],
#        [1496,  897],
#        [ 597,  898],
#        [ 598,  898],
#        [ 599,  898],
#        [ 600,  898],
#        [ 601,  898],
#        [ 602,  898],
#        [ 603,  898],
#        [ 604,  898],
#        [1489,  898],
#        [1490,  898],
#        [1491,  898],
#        [1492,  898],
#        [1493,  898],
#        [1494,  898],
#        [1495,  898],
#        [1496,  898],
#        [ 598,  899],
#        [ 599,  899],
#        [ 600,  899],
#        [ 601,  899],
#        [ 602,  899],
#        [ 603,  899],
#        [1490,  899],
#        [1491,  899],
#        [1492,  899],
#        [1493,  899],
#        [1494,  899],
#        [1495,  899],
#        [1493,  900],
#        [1311, 1059],
#        [1312, 1059],
#        [1313, 1059],
#        [1314, 1059],
#        [1315, 1059],
#        [1316, 1059],
#        [1490, 1059],
#        [1491, 1059],
#        [1492, 1059],
#        [1493, 1059],
#        [1494, 1059],
#        [1495, 1059],
#        [1310, 1060],
#        [1311, 1060],
#        [1312, 1060],
#        [1313, 1060],
#        [1314, 1060],
#        [1315, 1060],
#        [1316, 1060],
#        [1317, 1060],
#        [1489, 1060],
#        [1490, 1060],
#        [1491, 1060],
#        [1492, 1060],
#        [1493, 1060],
#        [1494, 1060],
#        [1495, 1060],
#        [1496, 1060],
#        [1310, 1061],
#        [1311, 1061],
#        [1312, 1061],
#        [1313, 1061],
#        [1314, 1061],
#        [1315, 1061],
#        [1316, 1061],
#        [1317, 1061],
#        [1318, 1061],
#        [1489, 1061],
#        [1490, 1061],
#        [1491, 1061],
#        [1492, 1061],
#        [1493, 1061],
#        [1494, 1061],
#        [1495, 1061],
#        [1496, 1061],
#        [1310, 1062],
#        [1311, 1062],
#        [1312, 1062],
#        [1313, 1062],
#        [1314, 1062],
#        [1315, 1062],
#        [1316, 1062],
#        [1317, 1062],
#        [1318, 1062],
#        [1489, 1062],
#        [1490, 1062],
#        [1491, 1062],
#        [1492, 1062],
#        [1493, 1062],
#        [1494, 1062],
#        [1495, 1062],
#        [1496, 1062],
#        [1311, 1063],
#        [1312, 1063],
#        [1313, 1063],
#        [1314, 1063],
#        [1315, 1063],
#        [1316, 1063],
#        [1317, 1063],
#        [1318, 1063],
#        [1490, 1063],
#        [1491, 1063],
#        [1492, 1063],
#        [1493, 1063],
#        [1494, 1063],
#        [1495, 1063],
#        [1496, 1063],
#        [1312, 1064],
#        [1313, 1064],
#        [1314, 1064],
#        [1315, 1064],
#        [1316, 1064],
#        [1492, 1064],
#        [1493, 1064],
#        [1494, 1064],
#        [1495, 1064],
#        [ 420, 1223],
#        [ 421, 1223],
#        [ 422, 1223],
#        [1134, 1223],
#        [1135, 1223],
#        [1136, 1223],
#        [ 419, 1224],
#        [ 420, 1224],
#        [ 421, 1224],
#        [ 422, 1224],
#        [ 423, 1224],
#        [ 424, 1224],
#        [1133, 1224],
#        [1134, 1224],
#        [1135, 1224],
#        [1136, 1224],
#        [1137, 1224],
#        [1138, 1224],
#        [ 418, 1225],
#        [ 419, 1225],
#        [ 420, 1225],
#        [ 421, 1225],
#        [ 422, 1225],
#        [ 423, 1225],
#        [ 424, 1225],
#        [ 425, 1225],
#        [1132, 1225],
#        [1133, 1225],
#        [1134, 1225],
#        [1135, 1225],
#        [1136, 1225],
#        [1137, 1225],
#        [1138, 1225],
#        [1139, 1225],
#        [ 418, 1226],
#        [ 419, 1226],
#        [ 420, 1226],
#        [ 421, 1226],
#        [ 422, 1226],
#        [ 423, 1226],
#        [ 424, 1226],
#        [ 425, 1226],
#        [1132, 1226],
#        [1133, 1226],
#        [1134, 1226],
#        [1135, 1226],
#        [1136, 1226],
#        [1137, 1226],
#        [1138, 1226],
#        [1139, 1226],
#        [ 419, 1227],
#        [ 420, 1227],
#        [ 421, 1227],
#        [ 422, 1227],
#        [ 423, 1227],
#        [ 424, 1227],
#        [ 425, 1227],
#        [1133, 1227],
#        [1134, 1227],
#        [1135, 1227],
#        [1136, 1227],
#        [1137, 1227],
#        [1138, 1227],
#        [1139, 1227],
#        [ 420, 1228],
#        [ 421, 1228],
#        [ 422, 1228],
#        [ 423, 1228],
#        [ 424, 1228],
#        [1134, 1228],
#        [1135, 1228],
#        [1136, 1228],
#        [1137, 1228],
#        [1138, 1228],
#        [ 598, 1388],
#        [ 599, 1388],
#        [ 600, 1388],
#        [ 601, 1388],
#        [ 602, 1388],
#        [1311, 1388],
#        [1312, 1388],
#        [1313, 1388],
#        [1314, 1388],
#        [1315, 1388],
#        [1316, 1388],
#        [ 597, 1389],
#        [ 598, 1389],
#        [ 599, 1389],
#        [ 600, 1389],
#        [ 601, 1389],
#        [ 602, 1389],
#        [ 603, 1389],
#        [1311, 1389],
#        [1312, 1389],
#        [1313, 1389],
#        [1314, 1389],
#        [1315, 1389],
#        [1316, 1389],
#        [1317, 1389],
#        [ 597, 1390],
#        [ 598, 1390],
#        [ 599, 1390],
#        [ 600, 1390],
#        [ 601, 1390],
#        [ 602, 1390],
#        [ 603, 1390],
#        [ 604, 1390],
#        [1310, 1390],
#        [1311, 1390],
#        [1312, 1390],
#        [1313, 1390],
#        [1314, 1390],
#        [1315, 1390],
#        [1316, 1390],
#        [1317, 1390],
#        [1318, 1390],
#        [ 597, 1391],
#        [ 598, 1391],
#        [ 599, 1391],
#        [ 600, 1391],
#        [ 601, 1391],
#        [ 602, 1391],
#        [ 603, 1391],
#        [ 604, 1391],
#        [1311, 1391],
#        [1312, 1391],
#        [1313, 1391],
#        [1314, 1391],
#        [1315, 1391],
#        [1316, 1391],
#        [1317, 1391],
#        [1318, 1391],
#        [ 598, 1392],
#        [ 599, 1392],
#        [ 600, 1392],
#        [ 601, 1392],
#        [ 602, 1392],
#        [ 603, 1392],
#        [1312, 1392],
#        [1313, 1392],
#        [1314, 1392],
#        [1315, 1392],
#        [1316, 1392],
#        [1317, 1392],
#        [ 601, 1393],
#        [1314, 1393],
#        [1315, 1393]])

# %%
# def maskit(array):
tolerance = tile_w*2
diff = np.empty(arr.shape)
diff[0] = np.inf  # always retain the 1st element
diff[1:] = np.diff(arr, axis=0)
mask = diff>tolerance.   
# return mask
mask.shape
# Out:
# (36, 2)

# %%
np.diff(arr,axis=0)
# Out:
# array([[   -2,     1],
#        [    0,     1],
#        [    0,     1],
#        [    0,     1],
#        [    1,     1],
#        [    2,     1],
#        [   -2,   159],
#        [ -712,   164],
#        [  892,     0],
#        [   -2,     1],
#        [    0,     1],
#        [    0,     1],
#        [    0,     1],
#        [    1,     1],
#        [ -179,   160],
#        [  179,     0],
#        [   -1,     1],
#        [    0,     1],
#        [    0,     1],
#        [    1,     1],
#        [    2,     1],
#        [-1072,   159],
#        [  714,     0],
#        [   -1,     1],
#        [   -1,     1],
#        [    0,     1],
#        [    1,     1],
#        [    1,     1],
#        [ -536,   160],
#        [  713,     0],
#        [    0,     1],
#        [   -1,     1],
#        [    1,     1],
#        [    1,     1],
#        [    2,     1]])

# %%
mask
# Out:
# array([[ True,  True],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False,  True],
#        [ True, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False,  True],
#        [ True, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False,  True],
#        [ True, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False],
#        [False, False]])

# %%
new_arr = arr

# %%
new_arr.shape
# Out:
# (10, 2)

# %%
fig, ax = plt.subplots()
ax.scatter(new_arr[:,0],new_arr[:,1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
for row in new_arr:
    perform(row)
    if pyautogui.locateCenterOnScreen('Images/btn_close.png', confidence=0.7):
        x, y = pyautogui.locateCenterOnScreen('Images/btn_close.png', confidence=0.7)
        pyautogui.click(x/2, y/2, duration=0.3, button='right')
        break

# %%
box = pyautogui.locateOnScreen('Images/candy_green.png', confidence=0.7)

# %%
pyautogui.click(box.left, box.top/2+offset_x)

# %%
box
# Out:
# Box(left=647, top=612, width=128, height=132)

# %%
perform(box)

# %%
arr = np.array([1,1, 1,1,1,2,1,2, 2, 1]).reshape([5, 2])

# %%
diff = np.diff(arr, axis=0)

# %%
np.diff(arr, axis=0)[:,1]
# Out:
# array([ 0,  1,  0, -1])

# %%
arr
# Out:
# array([[1, 1],
#        [1, 1],
#        [1, 2],
#        [1, 2],
#        [2, 1]])

# %%
diff = np.empty(arr.shape)

# %%
diff[0,:]=[np.inf, np.inf]

# %%
diff[1:,:]=np.diff(arr, axis=0)

# %%
mask = diff>0

# %%
arr[mask.any(axis=1)]
# Out:
# array([[1, 1],
#        [1, 2],
#        [2, 1]])

# %%
tolerance
# Out:
# 142.85714285714286
